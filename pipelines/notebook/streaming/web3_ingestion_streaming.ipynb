# %%
import os
import json
import uuid
import time
import asyncio
from confluent_kafka.serialization import SerializationContext, MessageField
from prometheus_client import start_http_server
from confluent_kafka import KafkaException
from src.metrics import *
from src.logging import log
from src.rpc_provider import Web3AsyncRouter, AsyncRpcClient, AsyncRpcScheduler, RpcPool, RpcErrorResult, RpcTaskMeta
from src.state import load_last_state
from src.kafka_utils import init_producer, get_serializers, delivery_report
from src.web3_utils import current_utctime, to_json_safe
# from src.commit_timer import CommitTimer
# from src.batch_executor import BatchContext, ParallelBatchExecutor
from src.safe_latest import SafeLatestBlockProvider

# -----------------------------
# Environment Variables
# -----------------------------
RUN_ID = os.getenv("RUN_ID", str(uuid.uuid4()))
POLL_INTERVAL = float(os.getenv("POLL_INTERVAL", "1")) # can be decimals
CHAIN = os.getenv("CHAIN", "bsc").lower() # bsc, eth, base ... from blockchain-rpc-config.yaml
RESUME_FROM_LAST = os.getenv("RESUME_FROM_LAST", "True").lower() in ("1", "true", "yes")

# -----------------------------
# Job Name & Kafka IDs
# -----------------------------
if RESUME_FROM_LAST:
    JOB_NAME = f"{CHAIN}_backfill_resume"        # 固定名，Kafka checkpoint 能被复用
else:
    JOB_NAME = f"{CHAIN}_realtime_{current_utctime()}"  # 每次唯一，从最新block开始

# -----------------------------
# RPC Config
# -----------------------------
RPC_CONFIG_PATH = "/etc/ingestion/rpc_providers.json"
RPC_MAX_TIMEOUT = int(os.getenv("RPC_MAX_TIMEOUT", "10"))
RPC_MAX_SUBMIT = int(os.getenv("RPC_MAX_SUBMIT", "15")) # how many blocks for every commit to Kafka
RPC_MAX_INFLIGHT = int(os.getenv("RPC_MAX_INFLIGHT", "10"))  # 并发数量

# -----------------------------
# Log fetching Config
# -----------------------------
RANGE_SIZE = int(os.getenv("RANGE_SIZE", "5")) # how many blocks of range to fetch for logs
BATCH_TX_SIZE = int(os.getenv("BATCH_TX_SIZE", "5"))  # Max 10 logs transaction per batch within a single block
SLIDING_SIZE = int(os.getenv("SLIDING_SIZE", "20"))

# -----------------------------
# Kafka Config
# -----------------------------
TRANSACTIONAL_ID = f"blockchain.ingestion.{CHAIN}.{current_utctime()}" # TRANSACTIONAL_ID每次不一样，EOS由Compact State Topic实现
KAFKA_BROKER = "redpanda.kafka.svc:9092"
SCHEMA_REGISTRY_URL = "http://redpanda.kafka.svc:8081"
BLOCKS_TOPIC = f"blockchain.logs.{CHAIN}"
STATE_TOPIC = f"blockchain.state.{CHAIN}"

# -----------------------------
# RPC Initilization
# -----------------------------
rpc_configs = json.load(open(RPC_CONFIG_PATH))
rpc_pool = RpcPool.from_config(rpc_configs, CHAIN)

# -----------------------------
# Kafka Producer initialization
# -----------------------------
blocks_value_serializer, state_value_serializer = get_serializers(SCHEMA_REGISTRY_URL, BLOCKS_TOPIC, STATE_TOPIC)
producer = init_producer(TRANSACTIONAL_ID, KAFKA_BROKER)
# Out:
# {"ts": "2026-01-23T09:58:09.857Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "quiknode", "key_envs": ["QUIKNODE_KEY"], "weight": 8}
# {"ts": "2026-01-23T09:58:09.858Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "infura", "key_envs": ["INFURA_KEY_A", "INFURA_KEY_B", "INFURA_KEY_C"], "weight": 8}
# {"ts": "2026-01-23T09:58:09.859Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "blockpi", "key_envs": ["BLOCKPI_BSC_KEY_A", "BLOCKPI_BSC_KEY_B", "BLOCKPI_BSC_KEY_C"], "weight": 8}
# {"ts": "2026-01-23T09:58:09.859Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "ankr", "key_envs": ["ANKR_KEY_A", "ANKR_KEY_B", "ANKR_KEY_C"], "weight": 6}
# {"ts": "2026-01-23T09:58:09.860Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "public-blxrbdn", "key_envs": ["public"], "weight": 2}
# {"ts": "2026-01-23T09:58:09.860Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "public-thirdweb", "key_envs": ["public"], "weight": 1}
# {"ts": "2026-01-23T09:58:09.860Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "public-nodies", "key_envs": ["public"], "weight": 1}
# {"ts": "2026-01-23T09:58:09.861Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "nownodes", "key_envs": ["NOWNODES_KEY_A"], "weight": 5}
# {"ts": "2026-01-23T09:58:09.861Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "drpc", "key_envs": ["DRPC_API_KEY_A", "DRPC_API_KEY_B"], "weight": 2}
# {"ts": "2026-01-23T09:58:09.873Z", "level": "INFO", "logger": "web3_ingestion", "msg": "Kafka_initializing...", "bootstrap_servers": "redpanda.kafka.svc:9092", "transactional_id": "blockchain.ingestion.bsc.2026-01-23T09:58:09.857Z"}

# %%
# Block Range 任务
from dataclasses import dataclass

@dataclass
class BlockRangeTask:
    range_id: int
    start_block: int
    end_block: int
    
# Range 执行结果（RPC → Kafka 的单位）
@dataclass
class RangeResult:
    range_id: int
    start_block: int
    end_block: int
    logs: list
    rpc: str
    key_env: str
    task_id: int


# Range Planner（顺序是从这里开始的）
def plan_block_ranges(start_block: int, end_block: int, range_size: int):
    range_id = 0
    b = start_block

    while b <= end_block:
        yield BlockRangeTask(
            range_id=range_id,
            start_block=b,
            end_block=min(b + range_size - 1, end_block),
        )
        b += range_size
        range_id += 1

# OrderedResultBuffer（保证顺序提交）- ingestion 的灵魂组件
class OrderedResultBuffer:
    def __init__(self):
        self._buffer = {}
        self._next_range_id = 0

    def add(self, result: RangeResult):
        self._buffer[result.range_id] = result

    def pop_ready(self):
        ready = []
        while self._next_range_id in self._buffer:
            ready.append(self._buffer.pop(self._next_range_id))
            self._next_range_id += 1
        return ready

# %%
class RangeCursor:
    def __init__(self, start_block: int, range_size: int):
        self.next_block = start_block
        self.range_size = range_size
        self.range_id = 0

    def next_range(self, max_block: int) -> BlockRangeTask | None:
        if self.next_block > max_block:
            return None

        start = self.next_block
        end = min(start + self.range_size - 1, max_block)

        r = BlockRangeTask(
            range_id=self.range_id,
            start_block=start,
            end_block=end,
        )

        self.next_block = end + 1
        self.range_id += 1
        return r

# %%
class LatestBlockTracker:
    def __init__(self, router, refresh_interval=2.0):
        self.router = router
        self.refresh_interval = refresh_interval
        self._latest = None
        self._last_refresh = 0.0
        self._lock = asyncio.Lock()

    async def get(self) -> int:
        async with self._lock:
            now = time.monotonic()
            if (
                self._latest is None
                or now - self._last_refresh >= self.refresh_interval
            ):
                self._latest = await self.router.get_latest_block()
                self._last_refresh = now
            return self._latest

# %%
async def submit_range(
    scheduler: AsyncRpcScheduler,
    r: BlockRangeTask,
):
    params = [{
        "fromBlock": hex(r.start_block),
        "toBlock": hex(r.end_block),
    }]

    return asyncio.create_task(
        scheduler.submit(
            "eth_getLogs",
            params,
            meta={
                "range_id": r.range_id,
                "start_block": r.start_block,
                "end_block": r.end_block,
            },
        )
    )

# %%
async def stream_ingest_logs(
    *,
    start_block: int,
    range_size: int,
    rpc_pool,
    producer,
    max_inflight_ranges: int = 20,
):
    # -----------------------------
    # RPC infra
    # -----------------------------
    client = AsyncRpcClient(timeout=RPC_MAX_TIMEOUT)
    router = Web3AsyncRouter(rpc_pool, client)

    scheduler = AsyncRpcScheduler(
        router=router,
        max_workers=1,
        max_inflight=RPC_MAX_INFLIGHT,
        max_queue=RPC_MAX_INFLIGHT * 3,
    )

    # -----------------------------
    # Control plane
    # -----------------------------
    latest_tracker = LatestBlockTracker(router, refresh_interval=2.0)
    cursor = RangeCursor(start_block, range_size)

    # -----------------------------
    # Ordering
    # -----------------------------
    ordered_buffer = OrderedResultBuffer()

    # -----------------------------
    # Inflight window
    # -----------------------------
    inflight: set[asyncio.Task] = set()

    # -----------------------------
    # 预填满滑动窗口
    # -----------------------------
    latest_block = await latest_tracker.get()

    while len(inflight) < max_inflight_ranges:
        r = cursor.next_range(latest_block)
        if not r:
            break
        inflight.add(await submit_range(scheduler, r))

    # -----------------------------
    # 主 streaming loop
    # -----------------------------
    while inflight:
        done, _ = await asyncio.wait(
            inflight,
            return_when=asyncio.FIRST_COMPLETED,
        )

        for task in done:
            inflight.remove(task)
            result = await task

            # ---------- RPC error ----------
            if isinstance(result, RpcErrorResult):
                log.error(
                    "rpc_range_failed",
                    extra={
                        "range_id": result.meta.extra.get("range_id"),
                        "error": type(result.error).__name__,
                    },
                )
                raise RuntimeError("range rpc failed")

            logs, rpc, key_env, trace, wid, meta = result

            rr = RangeResult(
                range_id=meta.extra["range_id"],
                start_block=meta.extra["start_block"],
                end_block=meta.extra["end_block"],
                logs=logs or [],
                rpc=rpc,
                key_env=key_env,
                task_id=meta.task_id,
            )

            ordered_buffer.add(rr)

            # ---------- 顺序消费 ----------
            ready_ranges = ordered_buffer.pop_ready()

            for rr in ready_ranges:
                # ===== Kafka EOS 写入 =====
                producer.begin_transaction()

                logs_by_block = {}
                for log_item in to_json_safe(rr.logs):
                    bn = log_item.get("blockNumber")
                    if bn is None:
                        continue
                    if isinstance(bn, str):
                        bn = int(bn, 16)
                    logs_by_block.setdefault(bn, []).append(log_item)

                for bn, txs in logs_by_block.items():
                    for idx, tx in enumerate(txs):
                        producer.produce(
                            topic=BLOCKS_TOPIC,
                            key=f"{bn}-{idx}",
                            value=blocks_value_serializer(
                                {
                                    "block_height": bn,
                                    "job_name": JOB_NAME,
                                    "run_id": RUN_ID,
                                    "inserted_at": current_utctime(),
                                    "raw": json.dumps(tx),
                                    "tx_index": idx,
                                },
                                SerializationContext(
                                    BLOCKS_TOPIC, MessageField.VALUE
                                ),
                            ),
                        )
                    producer.poll(0)

                # checkpoint
                producer.produce(
                    STATE_TOPIC,
                    key=JOB_NAME,
                    value=state_value_serializer(
                        {
                            "job_name": JOB_NAME,
                            "run_id": f"{RUN_ID}-task-{rr.task_id}",
                            "range": {
                                "start": rr.start_block,
                                "end": rr.end_block,
                            },
                            "checkpoint": rr.end_block,
                            "status": "running",
                            "inserted_at": current_utctime(),
                        },
                        SerializationContext(
                            STATE_TOPIC, MessageField.VALUE
                        ),
                    ),
                )
                producer.poll(0)
                producer.commit_transaction()

                log.info(
                    "range_committed",
                    extra={
                        "range_id": rr.range_id,
                        "start": rr.start_block,
                        "end": rr.end_block,
                        "rpc": rr.rpc,
                        "log_count": len(rr.logs),
                    },
                )

            # ---------- 下游释放 → 上游补位 ----------
            latest_block = await latest_tracker.get()

            while len(inflight) < max_inflight_ranges:
                r = cursor.next_range(latest_block)
                if not r:
                    break
                inflight.add(await submit_range(scheduler, r))

    # -----------------------------
    # shutdown
    # -----------------------------
    await scheduler.close()

# %%
# Entrypoint
if __name__ == "__main__":
    # Prometheus metrics endpoint
    # start_http_server(8000)

    last_state = load_last_state(
        job_name=JOB_NAME,
        kafka_broker=KAFKA_BROKER,
        state_topic=STATE_TOPIC,
        schema_registry_url=SCHEMA_REGISTRY_URL,
    )

    last_block = last_state["checkpoint"]

    start_block = last_block + 1

    await stream_ingest_logs(start_block=start_block,
        range_size=RANGE_SIZE,
        rpc_pool=rpc_pool,
        producer=producer)
# Out:
# {"ts": "2026-01-23T10:00:19.920Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatcher_started", "worker": 0}
# {"ts": "2026-01-23T10:00:20.194Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 1, "method": "eth_getLogs", "queue_wait_ms": 0.09}
# {"ts": "2026-01-23T10:00:20.195Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 2, "method": "eth_getLogs", "queue_wait_ms": 0.93}
# {"ts": "2026-01-23T10:00:20.195Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 3, "method": "eth_getLogs", "queue_wait_ms": 1.4}
# {"ts": "2026-01-23T10:00:20.195Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 4, "method": "eth_getLogs", "queue_wait_ms": 1.81}
# {"ts": "2026-01-23T10:00:20.196Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 5, "method": "eth_getLogs", "queue_wait_ms": 2.61}
# {"ts": "2026-01-23T10:00:20.197Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 6, "method": "eth_getLogs", "queue_wait_ms": 3.1}
# {"ts": "2026-01-23T10:00:20.197Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 7, "method": "eth_getLogs", "queue_wait_ms": 3.54}
# {"ts": "2026-01-23T10:00:20.198Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 8, "method": "eth_getLogs", "queue_wait_ms": 3.96}
# {"ts": "2026-01-23T10:00:20.198Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 9, "method": "eth_getLogs", "queue_wait_ms": 4.78}
# {"ts": "2026-01-23T10:00:20.199Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 10, "method": "eth_getLogs", "queue_wait_ms": 5.2}
# {"ts": "2026-01-23T10:00:20.199Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 11, "method": "eth_getLogs", "queue_wait_ms": 5.56}
# {"ts": "2026-01-23T10:00:20.200Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 12, "method": "eth_getLogs", "queue_wait_ms": 5.91}
# {"ts": "2026-01-23T10:00:20.200Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 13, "method": "eth_getLogs", "queue_wait_ms": 6.26}
# {"ts": "2026-01-23T10:00:20.200Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 14, "method": "eth_getLogs", "queue_wait_ms": 6.85}
# {"ts": "2026-01-23T10:00:20.201Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 15, "method": "eth_getLogs", "queue_wait_ms": 7.6}
# {"ts": "2026-01-23T10:00:20.202Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 16, "method": "eth_getLogs", "queue_wait_ms": 8.21}
# {"ts": "2026-01-23T10:00:20.202Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 17, "method": "eth_getLogs", "queue_wait_ms": 8.58}
# {"ts": "2026-01-23T10:00:20.203Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 18, "method": "eth_getLogs", "queue_wait_ms": 8.96}
# {"ts": "2026-01-23T10:00:20.203Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 19, "method": "eth_getLogs", "queue_wait_ms": 9.4}
# {"ts": "2026-01-23T10:00:20.204Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 20, "method": "eth_getLogs", "queue_wait_ms": 10.39}
# {"ts": "2026-01-23T10:00:20.205Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 1, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.207Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 2, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.207Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 3, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.208Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 4, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.209Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 5, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.209Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 6, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.210Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 7, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.211Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 8, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.211Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 9, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.212Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 10, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.658Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 9, "rpc": "public-blxrbdn", "key_env": "public", "latency_ms": 446.17}
# {"ts": "2026-01-23T10:00:20.658Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 11, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.660Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 21, "method": "eth_getLogs", "queue_wait_ms": 0.02}
# {"ts": "2026-01-23T10:00:20.695Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 3, "rpc": "drpc", "key_env": "DRPC_API_KEY_A", "latency_ms": 487.33}
# {"ts": "2026-01-23T10:00:20.696Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 12, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.697Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 22, "method": "eth_getLogs", "queue_wait_ms": 0.02}
# {"ts": "2026-01-23T10:00:20.922Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 2, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_A", "latency_ms": 714.91}
# {"ts": "2026-01-23T10:00:20.922Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 13, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:20.923Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 23, "method": "eth_getLogs", "queue_wait_ms": 0.03}
# {"ts": "2026-01-23T10:00:21.216Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 5, "rpc": "ankr", "key_env": "ANKR_KEY_B", "latency_ms": 1007.35}
# {"ts": "2026-01-23T10:00:21.217Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 14, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:21.218Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 24, "method": "eth_getLogs", "queue_wait_ms": 0.02}
# {"ts": "2026-01-23T10:00:21.256Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 4, "rpc": "ankr", "key_env": "ANKR_KEY_A", "latency_ms": 1047.59}
# {"ts": "2026-01-23T10:00:21.256Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 15, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:21.258Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 25, "method": "eth_getLogs", "queue_wait_ms": 0.04}
# {"ts": "2026-01-23T10:00:21.609Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 11, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_B", "latency_ms": 950.94}
# {"ts": "2026-01-23T10:00:21.619Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 16, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:21.620Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 13, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 698.12}
# {"ts": "2026-01-23T10:00:21.622Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 17, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:21.623Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 12, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_C", "latency_ms": 927.87}
# {"ts": "2026-01-23T10:00:21.624Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 18, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:21.626Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 26, "method": "eth_getLogs", "queue_wait_ms": 0.24}
# {"ts": "2026-01-23T10:00:21.627Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 27, "method": "eth_getLogs", "queue_wait_ms": 1.65}
# {"ts": "2026-01-23T10:00:21.629Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 8, "rpc": "ankr", "key_env": "ANKR_KEY_C", "latency_ms": 1418.84}
# {"ts": "2026-01-23T10:00:21.631Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 19, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:21.632Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 28, "method": "eth_getLogs", "queue_wait_ms": 1.11}
# {"ts": "2026-01-23T10:00:21.635Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 29, "method": "eth_getLogs", "queue_wait_ms": 0.16}
# {"ts": "2026-01-23T10:00:21.959Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 15, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_A", "latency_ms": 703.0}
# {"ts": "2026-01-23T10:00:21.960Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 20, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:22.055Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 10, "rpc": "infura", "key_env": "INFURA_KEY_C", "latency_ms": 1843.02}
# {"ts": "2026-01-23T10:00:22.056Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 21, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:22.069Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 6, "rpc": "infura", "key_env": "INFURA_KEY_A", "latency_ms": 1859.97}
# {"ts": "2026-01-23T10:00:22.070Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 22, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:22.099Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 7, "rpc": "infura", "key_env": "INFURA_KEY_B", "latency_ms": 1889.27}
# {"ts": "2026-01-23T10:00:22.100Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 23, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:22.146Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 1, "rpc": "nownodes", "key_env": "NOWNODES_KEY_A", "latency_ms": 1941.26}
# {"ts": "2026-01-23T10:00:22.147Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 24, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:22.465Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 30, "method": "eth_getLogs", "queue_wait_ms": 0.03}
# {"ts": "2026-01-23T10:00:22.523Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 0, "start": 76776882, "end": 76776886, "rpc": "nownodes", "log_count": 3178}
# {"ts": "2026-01-23T10:00:22.590Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 1, "start": 76776887, "end": 76776891, "rpc": "blockpi", "log_count": 3675}
# {"ts": "2026-01-23T10:00:22.642Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 2, "start": 76776892, "end": 76776896, "rpc": "drpc", "log_count": 3206}
# {"ts": "2026-01-23T10:00:22.692Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 3, "start": 76776897, "end": 76776901, "rpc": "ankr", "log_count": 2862}
# {"ts": "2026-01-23T10:00:22.749Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 4, "start": 76776902, "end": 76776906, "rpc": "ankr", "log_count": 3164}
# {"ts": "2026-01-23T10:00:22.811Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 5, "start": 76776907, "end": 76776911, "rpc": "infura", "log_count": 2983}
# {"ts": "2026-01-23T10:00:22.974Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 6, "start": 76776912, "end": 76776916, "rpc": "infura", "log_count": 3331}
# {"ts": "2026-01-23T10:00:23.040Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 7, "start": 76776917, "end": 76776921, "rpc": "ankr", "log_count": 3870}
# {"ts": "2026-01-23T10:00:23.092Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 8, "start": 76776922, "end": 76776926, "rpc": "public-blxrbdn", "log_count": 3398}
# {"ts": "2026-01-23T10:00:23.159Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 9, "start": 76776927, "end": 76776931, "rpc": "infura", "log_count": 3626}
# {"ts": "2026-01-23T10:00:23.213Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 10, "start": 76776932, "end": 76776936, "rpc": "blockpi", "log_count": 3209}
# {"ts": "2026-01-23T10:00:23.260Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 11, "start": 76776937, "end": 76776941, "rpc": "blockpi", "log_count": 2980}
# {"ts": "2026-01-23T10:00:23.319Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 12, "start": 76776942, "end": 76776946, "rpc": "quiknode", "log_count": 3934}
# {"ts": "2026-01-23T10:00:23.335Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 31, "method": "eth_getLogs", "queue_wait_ms": 14.61}
# {"ts": "2026-01-23T10:00:23.336Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 32, "method": "eth_getLogs", "queue_wait_ms": 15.5}
# {"ts": "2026-01-23T10:00:23.336Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 33, "method": "eth_getLogs", "queue_wait_ms": 16.17}
# {"ts": "2026-01-23T10:00:23.337Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 34, "method": "eth_getLogs", "queue_wait_ms": 16.9}
# {"ts": "2026-01-23T10:00:23.422Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 20, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 1461.73}
# {"ts": "2026-01-23T10:00:23.423Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 25, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:23.424Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 17, "rpc": "nownodes", "key_env": "NOWNODES_KEY_A", "latency_ms": 1801.89}
# {"ts": "2026-01-23T10:00:23.424Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 14, "rpc": "infura", "key_env": "INFURA_KEY_A", "latency_ms": 2207.65}
# {"ts": "2026-01-23T10:00:23.425Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 18, "rpc": "ankr", "key_env": "ANKR_KEY_A", "latency_ms": 1801.03}
# {"ts": "2026-01-23T10:00:23.426Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 16, "rpc": "public-nodies", "key_env": "public", "latency_ms": 1806.84}
# {"ts": "2026-01-23T10:00:23.428Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 23, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_C", "latency_ms": 1327.88}
# {"ts": "2026-01-23T10:00:23.429Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 26, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:23.432Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 27, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:23.433Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 28, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:23.434Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 29, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:23.435Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 30, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:23.522Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 13, "start": 76776947, "end": 76776951, "rpc": "infura", "log_count": 3700}
# {"ts": "2026-01-23T10:00:23.571Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 14, "start": 76776952, "end": 76776956, "rpc": "blockpi", "log_count": 2811}
# {"ts": "2026-01-23T10:00:23.721Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 15, "start": 76776957, "end": 76776961, "rpc": "public-nodies", "log_count": 4036}
# {"ts": "2026-01-23T10:00:23.819Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 16, "start": 76776962, "end": 76776966, "rpc": "nownodes", "log_count": 6142}
# {"ts": "2026-01-23T10:00:23.892Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 17, "start": 76776967, "end": 76776971, "rpc": "ankr", "log_count": 4132}
# {"ts": "2026-01-23T10:00:23.901Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 35, "method": "eth_getLogs", "queue_wait_ms": 7.13}
# {"ts": "2026-01-23T10:00:23.902Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 36, "method": "eth_getLogs", "queue_wait_ms": 7.7}
# {"ts": "2026-01-23T10:00:23.902Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 37, "method": "eth_getLogs", "queue_wait_ms": 8.17}
# {"ts": "2026-01-23T10:00:23.902Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 38, "method": "eth_getLogs", "queue_wait_ms": 8.63}
# {"ts": "2026-01-23T10:00:23.903Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 39, "method": "eth_getLogs", "queue_wait_ms": 9.03}
# {"ts": "2026-01-23T10:00:23.903Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 40, "method": "eth_getLogs", "queue_wait_ms": 9.53}
# {"ts": "2026-01-23T10:00:23.906Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 19, "rpc": "infura", "key_env": "INFURA_KEY_B", "latency_ms": 2275.17}
# {"ts": "2026-01-23T10:00:23.907Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 31, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:23.971Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 18, "start": 76776972, "end": 76776976, "rpc": "infura", "log_count": 3571}
# {"ts": "2026-01-23T10:00:24.029Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 19, "start": 76776977, "end": 76776981, "rpc": "quiknode", "log_count": 3695}
# {"ts": "2026-01-23T10:00:24.284Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 41, "method": "eth_getLogs", "queue_wait_ms": 0.03}
# {"ts": "2026-01-23T10:00:24.451Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 26, "rpc": "public-blxrbdn", "key_env": "public", "latency_ms": 1021.45}
# {"ts": "2026-01-23T10:00:24.451Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 32, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:24.454Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 42, "method": "eth_getLogs", "queue_wait_ms": 0.04}
# {"ts": "2026-01-23T10:00:24.640Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 27, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 1207.9}
# {"ts": "2026-01-23T10:00:24.641Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 33, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:24.642Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 43, "method": "eth_getLogs", "queue_wait_ms": 0.03}
# {"ts": "2026-01-23T10:00:25.004Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 32, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 552.88}
# {"ts": "2026-01-23T10:00:25.005Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 34, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:25.006Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 24, "rpc": "public-thirdweb", "key_env": "public", "latency_ms": 2859.85}
# {"ts": "2026-01-23T10:00:25.007Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 35, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:25.009Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 44, "method": "eth_getLogs", "queue_wait_ms": 0.76}
# {"ts": "2026-01-23T10:00:25.010Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 45, "method": "eth_getLogs", "queue_wait_ms": 0.57}
# {"ts": "2026-01-23T10:00:25.121Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 21, "rpc": "infura", "key_env": "INFURA_KEY_C", "latency_ms": 3065.06}
# {"ts": "2026-01-23T10:00:25.122Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 36, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:25.195Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 20, "start": 76776982, "end": 76776986, "rpc": "infura", "log_count": 4067}
# {"ts": "2026-01-23T10:00:25.202Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 46, "method": "eth_getLogs", "queue_wait_ms": 6.36}
# {"ts": "2026-01-23T10:00:25.328Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 22, "rpc": "public-thirdweb", "key_env": "public", "latency_ms": 3258.06}
# {"ts": "2026-01-23T10:00:25.329Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 37, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:25.330Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 29, "rpc": "ankr", "key_env": "ANKR_KEY_C", "latency_ms": 1895.23}
# {"ts": "2026-01-23T10:00:25.330Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 31, "rpc": "public-nodies", "key_env": "public", "latency_ms": 1423.28}
# {"ts": "2026-01-23T10:00:25.331Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 38, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:25.332Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 39, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:25.391Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 21, "start": 76776987, "end": 76776991, "rpc": "public-thirdweb", "log_count": 2998}
# {"ts": "2026-01-23T10:00:25.446Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 22, "start": 76776992, "end": 76776996, "rpc": "blockpi", "log_count": 3453}
# {"ts": "2026-01-23T10:00:25.509Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 23, "start": 76776997, "end": 76777001, "rpc": "public-thirdweb", "log_count": 3922}
# {"ts": "2026-01-23T10:00:25.510Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 25, "rpc": "ankr", "key_env": "ANKR_KEY_B", "latency_ms": 2087.77}
# {"ts": "2026-01-23T10:00:25.511Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 40, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:25.516Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 47, "method": "eth_getLogs", "queue_wait_ms": 4.54}
# {"ts": "2026-01-23T10:00:25.516Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 48, "method": "eth_getLogs", "queue_wait_ms": 4.95}
# {"ts": "2026-01-23T10:00:25.517Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 49, "method": "eth_getLogs", "queue_wait_ms": 5.56}
# {"ts": "2026-01-23T10:00:25.590Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 24, "start": 76777002, "end": 76777006, "rpc": "ankr", "log_count": 4188}
# {"ts": "2026-01-23T10:00:25.659Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 25, "start": 76777007, "end": 76777011, "rpc": "public-blxrbdn", "log_count": 4418}
# {"ts": "2026-01-23T10:00:25.720Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 26, "start": 76777012, "end": 76777016, "rpc": "quiknode", "log_count": 3636}
# {"ts": "2026-01-23T10:00:25.730Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 50, "method": "eth_getLogs", "queue_wait_ms": 8.21}
# {"ts": "2026-01-23T10:00:25.732Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 30, "rpc": "ankr", "key_env": "ANKR_KEY_A", "latency_ms": 2297.22}
# {"ts": "2026-01-23T10:00:25.733Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 41, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:25.738Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 51, "method": "eth_getLogs", "queue_wait_ms": 0.04}
# {"ts": "2026-01-23T10:00:26.004Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 36, "rpc": "ankr", "key_env": "ANKR_KEY_A", "latency_ms": 882.71}
# {"ts": "2026-01-23T10:00:26.005Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 42, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:26.007Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 52, "method": "eth_getLogs", "queue_wait_ms": 0.03}
# {"ts": "2026-01-23T10:00:26.033Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 33, "rpc": "ankr", "key_env": "ANKR_KEY_B", "latency_ms": 1392.27}
# {"ts": "2026-01-23T10:00:26.034Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 43, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:26.147Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 28, "rpc": "nownodes", "key_env": "NOWNODES_KEY_A", "latency_ms": 2714.06}
# {"ts": "2026-01-23T10:00:26.148Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 44, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:26.377Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 35, "rpc": "ankr", "key_env": "ANKR_KEY_C", "latency_ms": 1370.29}
# {"ts": "2026-01-23T10:00:26.379Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 45, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:26.381Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 37, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_B", "latency_ms": 1051.73}
# {"ts": "2026-01-23T10:00:26.382Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 46, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:26.444Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 39, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_C", "latency_ms": 1112.55}
# {"ts": "2026-01-23T10:00:26.445Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 47, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:26.467Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 41, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_A", "latency_ms": 733.81}
# {"ts": "2026-01-23T10:00:26.467Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 48, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:26.592Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 43, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 558.46}
# {"ts": "2026-01-23T10:00:26.593Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 49, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:26.962Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 48, "rpc": "drpc", "key_env": "DRPC_API_KEY_B", "latency_ms": 494.87}
# {"ts": "2026-01-23T10:00:26.963Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 50, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:27.115Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 47, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_B", "latency_ms": 670.28}
# {"ts": "2026-01-23T10:00:27.117Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 51, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:27.123Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 53, "method": "eth_getLogs", "queue_wait_ms": 0.02}
# {"ts": "2026-01-23T10:00:27.181Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 27, "start": 76777017, "end": 76777021, "rpc": "nownodes", "log_count": 3286}
# {"ts": "2026-01-23T10:00:27.234Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 28, "start": 76777022, "end": 76777026, "rpc": "ankr", "log_count": 3062}
# {"ts": "2026-01-23T10:00:27.298Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 29, "start": 76777027, "end": 76777031, "rpc": "ankr", "log_count": 3370}
# {"ts": "2026-01-23T10:00:27.380Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 30, "start": 76777032, "end": 76777036, "rpc": "public-nodies", "log_count": 3965}
# {"ts": "2026-01-23T10:00:27.442Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 31, "start": 76777037, "end": 76777041, "rpc": "quiknode", "log_count": 3644}
# {"ts": "2026-01-23T10:00:27.503Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 32, "start": 76777042, "end": 76777046, "rpc": "ankr", "log_count": 3460}
# {"ts": "2026-01-23T10:00:27.519Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 54, "method": "eth_getLogs", "queue_wait_ms": 11.31}
# {"ts": "2026-01-23T10:00:27.519Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 55, "method": "eth_getLogs", "queue_wait_ms": 11.95}
# {"ts": "2026-01-23T10:00:27.520Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 56, "method": "eth_getLogs", "queue_wait_ms": 12.49}
# {"ts": "2026-01-23T10:00:27.520Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 57, "method": "eth_getLogs", "queue_wait_ms": 12.85}
# {"ts": "2026-01-23T10:00:27.521Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 58, "method": "eth_getLogs", "queue_wait_ms": 13.88}
# {"ts": "2026-01-23T10:00:27.522Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 59, "method": "eth_getLogs", "queue_wait_ms": 14.32}
# {"ts": "2026-01-23T10:00:27.522Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 60, "method": "eth_getLogs", "queue_wait_ms": 14.7}
# {"ts": "2026-01-23T10:00:27.522Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 61, "method": "eth_getLogs", "queue_wait_ms": 15.06}
# {"ts": "2026-01-23T10:00:27.670Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 42, "rpc": "ankr", "key_env": "ANKR_KEY_B", "latency_ms": 1664.84}
# {"ts": "2026-01-23T10:00:27.676Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 52, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:27.686Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 49, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_C", "latency_ms": 1093.31}
# {"ts": "2026-01-23T10:00:27.688Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 53, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:27.690Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 62, "method": "eth_getLogs", "queue_wait_ms": 1.63}
# {"ts": "2026-01-23T10:00:27.690Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 40, "rpc": "infura", "key_env": "INFURA_KEY_B", "latency_ms": 2178.98}
# {"ts": "2026-01-23T10:00:27.701Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 54, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:27.703Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 50, "rpc": "drpc", "key_env": "DRPC_API_KEY_A", "latency_ms": 740.58}
# {"ts": "2026-01-23T10:00:27.704Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 63, "method": "eth_getLogs", "queue_wait_ms": 1.28}
# {"ts": "2026-01-23T10:00:27.705Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 55, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:27.707Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 64, "method": "eth_getLogs", "queue_wait_ms": 0.82}
# {"ts": "2026-01-23T10:00:27.708Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 38, "rpc": "infura", "key_env": "INFURA_KEY_A", "latency_ms": 2376.6}
# {"ts": "2026-01-23T10:00:27.709Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 56, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:27.710Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 65, "method": "eth_getLogs", "queue_wait_ms": 1.2}
# {"ts": "2026-01-23T10:00:27.711Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 66, "method": "eth_getLogs", "queue_wait_ms": 0.15}
# {"ts": "2026-01-23T10:00:27.859Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 46, "rpc": "public-nodies", "key_env": "public", "latency_ms": 1476.68}
# {"ts": "2026-01-23T10:00:27.860Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 57, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:27.862Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 67, "method": "eth_getLogs", "queue_wait_ms": 0.05}
# {"ts": "2026-01-23T10:00:28.152Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 51, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_A", "latency_ms": 1035.19}
# {"ts": "2026-01-23T10:00:28.153Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 58, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:28.236Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 34, "rpc": "public-thirdweb", "key_env": "public", "latency_ms": 3231.01}
# {"ts": "2026-01-23T10:00:28.236Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 59, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:28.238Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 55, "rpc": "drpc", "key_env": "DRPC_API_KEY_B", "latency_ms": 532.57}
# {"ts": "2026-01-23T10:00:28.239Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 60, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:28.287Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 52, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 610.84}
# {"ts": "2026-01-23T10:00:28.288Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 61, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:28.305Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 53, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_B", "latency_ms": 616.89}
# {"ts": "2026-01-23T10:00:28.306Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 62, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:28.386Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 54, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_C", "latency_ms": 684.37}
# {"ts": "2026-01-23T10:00:28.387Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 63, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:28.596Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 68, "method": "eth_getLogs", "queue_wait_ms": 0.03}
# {"ts": "2026-01-23T10:00:28.671Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 33, "start": 76777047, "end": 76777051, "rpc": "public-thirdweb", "log_count": 4193}
# {"ts": "2026-01-23T10:00:28.752Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 34, "start": 76777052, "end": 76777056, "rpc": "ankr", "log_count": 3488}
# {"ts": "2026-01-23T10:00:28.826Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 35, "start": 76777057, "end": 76777061, "rpc": "ankr", "log_count": 3543}
# {"ts": "2026-01-23T10:00:29.009Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 36, "start": 76777062, "end": 76777066, "rpc": "blockpi", "log_count": 4121}
# {"ts": "2026-01-23T10:00:29.084Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 37, "start": 76777067, "end": 76777071, "rpc": "infura", "log_count": 4314}
# {"ts": "2026-01-23T10:00:29.175Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 38, "start": 76777072, "end": 76777076, "rpc": "blockpi", "log_count": 3816}
# {"ts": "2026-01-23T10:00:29.235Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 39, "start": 76777077, "end": 76777081, "rpc": "infura", "log_count": 2823}
# {"ts": "2026-01-23T10:00:29.303Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 40, "start": 76777082, "end": 76777086, "rpc": "blockpi", "log_count": 3459}
# {"ts": "2026-01-23T10:00:29.390Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 41, "start": 76777087, "end": 76777091, "rpc": "ankr", "log_count": 3609}
# {"ts": "2026-01-23T10:00:29.461Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 42, "start": 76777092, "end": 76777096, "rpc": "quiknode", "log_count": 3262}
# {"ts": "2026-01-23T10:00:29.485Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 69, "method": "eth_getLogs", "queue_wait_ms": 14.05}
# {"ts": "2026-01-23T10:00:29.485Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 70, "method": "eth_getLogs", "queue_wait_ms": 14.81}
# {"ts": "2026-01-23T10:00:29.486Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 71, "method": "eth_getLogs", "queue_wait_ms": 15.3}
# {"ts": "2026-01-23T10:00:29.486Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 72, "method": "eth_getLogs", "queue_wait_ms": 15.73}
# {"ts": "2026-01-23T10:00:29.487Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 73, "method": "eth_getLogs", "queue_wait_ms": 16.26}
# {"ts": "2026-01-23T10:00:29.541Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 45, "rpc": "infura", "key_env": "INFURA_KEY_A", "latency_ms": 3162.26}
# {"ts": "2026-01-23T10:00:29.541Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 64, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:29.542Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 58, "rpc": "drpc", "key_env": "DRPC_API_KEY_A", "latency_ms": 1389.57}
# {"ts": "2026-01-23T10:00:29.543Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 65, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:29.544Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 60, "rpc": "public-blxrbdn", "key_env": "public", "latency_ms": 1305.72}
# {"ts": "2026-01-23T10:00:29.545Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 59, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_A", "latency_ms": 1308.98}
# {"ts": "2026-01-23T10:00:29.547Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 57, "rpc": "public-nodies", "key_env": "public", "latency_ms": 1687.33}
# {"ts": "2026-01-23T10:00:29.547Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 61, "rpc": "ankr", "key_env": "ANKR_KEY_A", "latency_ms": 1259.7}
# {"ts": "2026-01-23T10:00:29.549Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 66, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:29.551Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 67, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:29.553Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 68, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:29.554Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 69, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:29.555Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 74, "method": "eth_getLogs", "queue_wait_ms": 0.19}
# {"ts": "2026-01-23T10:00:29.555Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 75, "method": "eth_getLogs", "queue_wait_ms": 0.96}
# {"ts": "2026-01-23T10:00:29.559Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 76, "method": "eth_getLogs", "queue_wait_ms": 2.12}
# {"ts": "2026-01-23T10:00:29.560Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 77, "method": "eth_getLogs", "queue_wait_ms": 3.11}
# {"ts": "2026-01-23T10:00:29.561Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 78, "method": "eth_getLogs", "queue_wait_ms": 3.73}
# {"ts": "2026-01-23T10:00:29.562Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 79, "method": "eth_getLogs", "queue_wait_ms": 5.09}
# {"ts": "2026-01-23T10:00:30.057Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 67, "rpc": "drpc", "key_env": "DRPC_API_KEY_B", "latency_ms": 506.22}
# {"ts": "2026-01-23T10:00:30.058Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 70, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:30.059Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 80, "method": "eth_getLogs", "queue_wait_ms": 0.03}
# {"ts": "2026-01-23T10:00:30.111Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 66, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 562.36}
# {"ts": "2026-01-23T10:00:30.112Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 71, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:30.113Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 81, "method": "eth_getLogs", "queue_wait_ms": 0.05}
# {"ts": "2026-01-23T10:00:30.633Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 68, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_B", "latency_ms": 1080.34}
# {"ts": "2026-01-23T10:00:30.634Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 72, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:30.770Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 71, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_C", "latency_ms": 657.98}
# {"ts": "2026-01-23T10:00:30.771Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 73, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:30.886Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 69, "rpc": "public-nodies", "key_env": "public", "latency_ms": 1332.42}
# {"ts": "2026-01-23T10:00:30.887Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 74, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:31.043Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 62, "rpc": "infura", "key_env": "INFURA_KEY_B", "latency_ms": 2737.0}
# {"ts": "2026-01-23T10:00:31.043Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 75, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:31.045Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 63, "rpc": "infura", "key_env": "INFURA_KEY_C", "latency_ms": 2658.0}
# {"ts": "2026-01-23T10:00:31.045Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 76, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:31.232Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 72, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 598.7}
# {"ts": "2026-01-23T10:00:31.233Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 77, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:31.574Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 65, "rpc": "nownodes", "key_env": "NOWNODES_KEY_A", "latency_ms": 2031.25}
# {"ts": "2026-01-23T10:00:31.575Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 78, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:31.615Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 64, "rpc": "infura", "key_env": "INFURA_KEY_A", "latency_ms": 2074.0}
# {"ts": "2026-01-23T10:00:31.617Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 79, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:31.632Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 76, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_A", "latency_ms": 586.58}
# {"ts": "2026-01-23T10:00:31.633Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 80, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:00:31.713Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 82, "method": "eth_getLogs", "queue_wait_ms": 0.03}
# {"ts": "2026-01-23T10:00:31.715Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 83, "method": "eth_getLogs", "queue_wait_ms": 0.49}
# {"ts": "2026-01-23T10:00:31.715Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 84, "method": "eth_getLogs", "queue_wait_ms": 0.87}
# {"ts": "2026-01-23T10:00:31.716Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 85, "method": "eth_getLogs", "queue_wait_ms": 1.49}
# {"ts": "2026-01-23T10:00:31.716Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 86, "method": "eth_getLogs", "queue_wait_ms": 1.85}
# {"ts": "2026-01-23T10:00:31.717Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 87, "method": "eth_getLogs", "queue_wait_ms": 2.46}
# {"ts": "2026-01-23T10:00:31.717Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 88, "method": "eth_getLogs", "queue_wait_ms": 2.94}
# {"ts": "2026-01-23T10:00:31.718Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 89, "method": "eth_getLogs", "queue_wait_ms": 3.49}
# ...
# {"ts": "2026-01-23T10:01:22.545Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 382, "method": "eth_getLogs", "queue_wait_ms": 3.38}
# {"ts": "2026-01-23T10:01:22.567Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 364, "rpc": "ankr", "key_env": "ANKR_KEY_B", "latency_ms": 1162.58}
# {"ts": "2026-01-23T10:01:22.567Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 373, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:22.570Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 383, "method": "eth_getLogs", "queue_wait_ms": 0.06}
# {"ts": "2026-01-23T10:01:22.620Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 365, "rpc": "public-nodies", "key_env": "public", "latency_ms": 1073.58}
# {"ts": "2026-01-23T10:01:22.621Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 374, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:22.622Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 384, "method": "eth_getLogs", "queue_wait_ms": 0.03}
# {"ts": "2026-01-23T10:01:23.118Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 368, "rpc": "ankr", "key_env": "ANKR_KEY_C", "latency_ms": 1306.68}
# {"ts": "2026-01-23T10:01:23.118Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 375, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:23.119Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 385, "method": "eth_getLogs", "queue_wait_ms": 0.04}
# {"ts": "2026-01-23T10:01:23.322Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 367, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 1639.96}
# {"ts": "2026-01-23T10:01:23.323Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 376, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:23.324Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 386, "method": "eth_getLogs", "queue_wait_ms": 0.02}
# {"ts": "2026-01-23T10:01:23.402Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 359, "rpc": "infura", "key_env": "INFURA_KEY_B", "latency_ms": 2273.04}
# {"ts": "2026-01-23T10:01:23.402Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 377, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:23.456Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 358, "start": 76778672, "end": 76778676, "rpc": "infura", "log_count": 3037}
# {"ts": "2026-01-23T10:01:23.598Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 359, "start": 76778677, "end": 76778681, "rpc": "blockpi", "log_count": 3176}
# {"ts": "2026-01-23T10:01:23.647Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 360, "start": 76778682, "end": 76778686, "rpc": "public-blxrbdn", "log_count": 2985}
# {"ts": "2026-01-23T10:01:23.734Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 362, "rpc": "infura", "key_env": "INFURA_KEY_C", "latency_ms": 2473.27}
# {"ts": "2026-01-23T10:01:23.734Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 378, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:23.735Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 373, "rpc": "ankr", "key_env": "ANKR_KEY_A", "latency_ms": 1167.99}
# {"ts": "2026-01-23T10:01:23.736Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 379, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:23.996Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 376, "rpc": "drpc", "key_env": "DRPC_API_KEY_A", "latency_ms": 673.11}
# {"ts": "2026-01-23T10:01:23.997Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 380, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:24.197Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 375, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_C", "latency_ms": 1079.0}
# {"ts": "2026-01-23T10:01:24.198Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 381, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:24.278Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 379, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 541.7}
# {"ts": "2026-01-23T10:01:24.278Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 382, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:24.324Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 369, "rpc": "infura", "key_env": "INFURA_KEY_A", "latency_ms": 1891.4}
# {"ts": "2026-01-23T10:01:24.325Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 383, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:24.364Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 372, "rpc": "infura", "key_env": "INFURA_KEY_C", "latency_ms": 1922.49}
# {"ts": "2026-01-23T10:01:24.364Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 384, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:24.365Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 371, "rpc": "infura", "key_env": "INFURA_KEY_B", "latency_ms": 1926.45}
# {"ts": "2026-01-23T10:01:24.366Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 385, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:24.720Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 382, "rpc": "public-blxrbdn", "key_env": "public", "latency_ms": 441.39}
# {"ts": "2026-01-23T10:01:24.720Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 386, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:24.723Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 387, "method": "eth_getLogs", "queue_wait_ms": 0.04}
# {"ts": "2026-01-23T10:01:24.784Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 361, "start": 76778687, "end": 76778691, "rpc": "infura", "log_count": 3257}
# {"ts": "2026-01-23T10:01:24.858Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 362, "start": 76778692, "end": 76778696, "rpc": "blockpi", "log_count": 3209}
# {"ts": "2026-01-23T10:01:24.920Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 363, "start": 76778697, "end": 76778701, "rpc": "ankr", "log_count": 3175}
# {"ts": "2026-01-23T10:01:24.983Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 364, "start": 76778702, "end": 76778706, "rpc": "public-nodies", "log_count": 3342}
# {"ts": "2026-01-23T10:01:25.146Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 365, "start": 76778707, "end": 76778711, "rpc": "drpc", "log_count": 3277}
# {"ts": "2026-01-23T10:01:25.255Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 366, "start": 76778712, "end": 76778716, "rpc": "quiknode", "log_count": 5582}
# {"ts": "2026-01-23T10:01:25.337Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 367, "start": 76778717, "end": 76778721, "rpc": "ankr", "log_count": 3420}
# {"ts": "2026-01-23T10:01:25.401Z", "level": "INFO", "logger": "web3_ingestion", "msg": "range_committed", "range_id": 368, "start": 76778722, "end": 76778726, "rpc": "infura", "log_count": 2994}
# {"ts": "2026-01-23T10:01:25.412Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 388, "method": "eth_getLogs", "queue_wait_ms": 10.3}
# {"ts": "2026-01-23T10:01:25.413Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 389, "method": "eth_getLogs", "queue_wait_ms": 10.83}
# {"ts": "2026-01-23T10:01:25.413Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 390, "method": "eth_getLogs", "queue_wait_ms": 11.48}
# {"ts": "2026-01-23T10:01:25.414Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 391, "method": "eth_getLogs", "queue_wait_ms": 12.14}
# {"ts": "2026-01-23T10:01:25.416Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 392, "method": "eth_getLogs", "queue_wait_ms": 13.84}
# {"ts": "2026-01-23T10:01:25.417Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 393, "method": "eth_getLogs", "queue_wait_ms": 15.53}
# {"ts": "2026-01-23T10:01:25.418Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 394, "method": "eth_getLogs", "queue_wait_ms": 16.31}
# {"ts": "2026-01-23T10:01:25.419Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 395, "method": "eth_getLogs", "queue_wait_ms": 16.79}
# {"ts": "2026-01-23T10:01:25.420Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 396, "method": "eth_getLogs", "queue_wait_ms": 17.71}
# ---------------------------------------------------------------------------
# CancelledError                            Traceback (most recent call last)
# Cell In[14], line 12
#       8 last_block = last_state["checkpoint"]
#      10 start_block = last_block + 1
# ---> 12 await stream_ingest_logs(start_block=start_block,
#      13     range_size=RANGE_SIZE,
#      14     rpc_pool=rpc_pool,
#      15     producer=producer)
#
# Cell In[11], line 53, in stream_ingest_logs(start_block, range_size, rpc_pool, producer, max_inflight_ranges)
#      49 # -----------------------------
#      50 # 主 streaming loop
#      51 # -----------------------------
#      52 while inflight:
# ---> 53     done, _ = await asyncio.wait(
#      54         inflight,
#      55         return_when=asyncio.FIRST_COMPLETED,
#      56     )
#      58     for task in done:
#      59         inflight.remove(task)
#
# File /opt/conda/lib/python3.11/asyncio/tasks.py:428, in wait(fs, timeout, return_when)
#     425     raise TypeError("Passing coroutines is forbidden, use tasks explicitly.")
#     427 loop = events.get_running_loop()
# --> 428 return await _wait(fs, timeout, return_when, loop)
#
# File /opt/conda/lib/python3.11/asyncio/tasks.py:535, in _wait(fs, timeout, return_when, loop)
#     532     f.add_done_callback(_on_completion)
#     534 try:
# --> 535     await waiter
#     536 finally:
#     537     if timeout_handle is not None:
#
# CancelledError:
# {"ts": "2026-01-23T10:01:25.513Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 370, "rpc": "nownodes", "key_env": "NOWNODES_KEY_A", "latency_ms": 3074.73}
# {"ts": "2026-01-23T10:01:25.514Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 387, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:25.516Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 377, "rpc": "ankr", "key_env": "ANKR_KEY_B", "latency_ms": 2113.4}
# {"ts": "2026-01-23T10:01:25.516Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 388, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:25.518Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 383, "rpc": "drpc", "key_env": "DRPC_API_KEY_B", "latency_ms": 1192.56}
# {"ts": "2026-01-23T10:01:25.519Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 389, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:25.521Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 374, "rpc": "public-thirdweb", "key_env": "public", "latency_ms": 2899.65}
# {"ts": "2026-01-23T10:01:25.522Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 390, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:25.580Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 378, "rpc": "infura", "key_env": "INFURA_KEY_B", "latency_ms": 1846.1}
# {"ts": "2026-01-23T10:01:25.581Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 391, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:25.617Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 380, "rpc": "ankr", "key_env": "ANKR_KEY_C", "latency_ms": 1620.11}
# {"ts": "2026-01-23T10:01:25.618Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 392, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:25.681Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 385, "rpc": "ankr", "key_env": "ANKR_KEY_A", "latency_ms": 1314.81}
# {"ts": "2026-01-23T10:01:25.682Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 393, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:25.905Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 386, "rpc": "ankr", "key_env": "ANKR_KEY_B", "latency_ms": 1184.9}
# {"ts": "2026-01-23T10:01:25.906Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 394, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:26.018Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 392, "rpc": "public-blxrbdn", "key_env": "public", "latency_ms": 400.0}
# {"ts": "2026-01-23T10:01:26.018Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 395, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:26.109Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 393, "rpc": "ankr", "key_env": "ANKR_KEY_C", "latency_ms": 427.58}
# {"ts": "2026-01-23T10:01:26.110Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 396, "method": "eth_getLogs"}
# {"ts": "2026-01-23T10:01:26.274Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 388, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "latency_ms": 757.58}
# {"ts": "2026-01-23T10:01:26.275Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 387, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_A", "latency_ms": 760.57}
# {"ts": "2026-01-23T10:01:26.277Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 389, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_B", "latency_ms": 757.61}
# {"ts": "2026-01-23T10:01:26.346Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 394, "rpc": "public-blxrbdn", "key_env": "public", "latency_ms": 440.3}
# {"ts": "2026-01-23T10:01:26.469Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 381, "rpc": "nownodes", "key_env": "NOWNODES_KEY_A", "latency_ms": 2271.08}
# {"ts": "2026-01-23T10:01:26.764Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 384, "rpc": "infura", "key_env": "INFURA_KEY_C", "latency_ms": 2399.08}
# {"ts": "2026-01-23T10:01:26.886Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 396, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_C", "latency_ms": 776.02}
# {"ts": "2026-01-23T10:01:27.395Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 391, "rpc": "infura", "key_env": "INFURA_KEY_A", "latency_ms": 1813.57}
# {"ts": "2026-01-23T10:01:27.586Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 395, "rpc": "ankr", "key_env": "ANKR_KEY_A", "latency_ms": 1567.77}
# {"ts": "2026-01-23T10:01:27.640Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 390, "rpc": "nownodes", "key_env": "NOWNODES_KEY_A", "latency_ms": 2118.21}
