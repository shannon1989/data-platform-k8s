# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.getOrCreate()
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/01/11 08:01:51 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/01/11 08:01:51 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.

# %%
# show Iceberg
spark.sql("SHOW CATALOGS").show()
# Out:
# +-------------+
# |      catalog|
# +-------------+
# |spark_catalog|
# +-------------+

# %%
spark.sql("SHOW NAMESPACES IN spark_catalog").show()
# Out:
# +---------+
# |namespace|
# +---------+
# |  default|
# +---------+

# %% [markdown]
# ### 1️⃣ Create namespace（database/schema）

# %%
spark.sql("""
CREATE TABLE silver.eth_blocks_t01 (
  id INT,
  name STRING
) USING iceberg
""")

spark.sql("INSERT INTO silver.eth_blocks_t01 VALUES (1, 't01')")
spark.sql("SELECT * FROM silver.eth_blocks_t01").show()

# %%
spark.sql("""
CREATE TABLE gold.eth_blocks_t01 (
  id INT,
  name STRING
) USING iceberg
""")

spark.sql("INSERT INTO gold.eth_blocks_t01 VALUES (1, 't01')")
spark.sql("SELECT * FROM gold.eth_blocks_t01").show()
