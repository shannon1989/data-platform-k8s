# %%
import os
import json
import asyncio
from src.rpc_provider import Web3AsyncRouter, AsyncRpcClient, AsyncRpcScheduler, RpcPool, RpcErrorResult
from src.logging import log
from src.web3_utils import current_utctime, normalize_block

# -----------------------------
# 配置
# -----------------------------
RPC_CONFIG_PATH = "/etc/ingestion/rpc_providers.json"

CHAIN = os.getenv("CHAIN", "bsc").lower()
RESUME_FROM_LAST = os.getenv("RESUME_FROM_LAST", "True").lower() in ("1", "true", "yes")

# -----------------------------
# Job Name & Kafka IDs
# -----------------------------
if RESUME_FROM_LAST:
    JOB_NAME = f"{CHAIN}_backfill_resume"        # 固定名，Kafka checkpoint 能被复用
else:
    JOB_NAME = f"{CHAIN}_realtime_{current_utctime()}"  # 每次唯一，从最新block开始

RPC_MAX_TIMEOUT = int(os.getenv("RPC_MAX_TIMEOUT", "10"))
RPC_MAX_INFLIGHT = int(os.getenv("RPC_MAX_INFLIGHT", "5"))  # 并发数量
TRANSACTIONAL_ID = f"blockchain.ingestion.{CHAIN}.{current_utctime()}" # TRANSACTIONAL_ID每次不一样，EOS由Compact State Topic实现

# -----------------------------
# 加载 RPC 配置
# -----------------------------
rpc_configs = json.load(open(RPC_CONFIG_PATH))

# 初始化rpc pool
rpc_pool = RpcPool.from_config(rpc_configs, CHAIN)
# Out:
# {"ts": "2026-01-22T14:50:16.728Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "quiknode", "key_envs": ["QUIKNODE_KEY"], "weight": 8}
# {"ts": "2026-01-22T14:50:16.729Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "moralis", "key_envs": ["MORALIS_KEY_B"], "weight": 8}
# {"ts": "2026-01-22T14:50:16.729Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "infura", "key_envs": ["INFURA_KEY_A", "INFURA_KEY_B", "INFURA_KEY_C"], "weight": 8}
# {"ts": "2026-01-22T14:50:16.730Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "blockpi", "key_envs": ["BLOCKPI_BSC_KEY_A", "BLOCKPI_BSC_KEY_B", "BLOCKPI_BSC_KEY_C"], "weight": 8}
# {"ts": "2026-01-22T14:50:16.731Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "ankr", "key_envs": ["ANKR_KEY_A", "ANKR_KEY_B", "ANKR_KEY_C"], "weight": 6}
# {"ts": "2026-01-22T14:50:16.731Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "public-blxrbdn", "key_envs": ["public"], "weight": 2}
# {"ts": "2026-01-22T14:50:16.731Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "public-thirdweb", "key_envs": ["public"], "weight": 1}
# {"ts": "2026-01-22T14:50:16.732Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "public-nodies", "key_envs": ["public"], "weight": 1}
# {"ts": "2026-01-22T14:50:16.733Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "nownodes", "key_envs": ["NOWNODES_KEY_A"], "weight": 5}
# {"ts": "2026-01-22T14:50:16.733Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_enabled", "chain": "bsc", "rpc": "drpc", "key_envs": ["DRPC_API_KEY_A", "DRPC_API_KEY_B"], "weight": 2}

# %%
async def fetch_and_push():
    client = AsyncRpcClient(timeout=RPC_MAX_TIMEOUT)
    router = Web3AsyncRouter(rpc_pool, client)
    scheduler = AsyncRpcScheduler(
        router=router,
        max_workers = 1,
        max_inflight=RPC_MAX_INFLIGHT,  #🔥 真正并发 RPC 数 # max_inflight ≈ (provider 数 × key 数) × 0.6
        max_queue=RPC_MAX_INFLIGHT * 5,
    )
    
    tasks = []
    
    for _ in range(20):
        tasks.append(
            asyncio.create_task(
                scheduler.submit("eth_blockNumber", [])
            )
        )
    
    results = await asyncio.gather(*tasks)

    for r in results:
        if isinstance(r, RpcErrorResult):
            log.warning(
                "rpc_failed",
                extra={
                    "provider": r.rpc,
                    "key": r.key_env,
                    "task_id": r.meta.task_id,
                    "worker": r.wid,
                    "error": type(r.error).__name__,
                },
            )
            continue
    
        result, rpc, key_env, trace, _, meta = r
        block_num = normalize_block(result)
    
        log.info(
            "rpc_call_done",
            extra={
                "task_id": meta.task_id,
                "rpc": rpc,
                "key_env": key_env,
                "block": block_num,
                "latency_ms": round(trace.total_ms, 2),
            },
        )

    await scheduler.close()

# %%
# worker as dispatcher - V3
await fetch_and_push()
# Out:
# {"ts": "2026-01-22T14:51:25.635Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatcher_started", "worker": 0}
# {"ts": "2026-01-22T14:51:25.637Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 1, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 0.12}
# {"ts": "2026-01-22T14:51:25.638Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 2, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 1.0}
# {"ts": "2026-01-22T14:51:25.638Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 3, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 1.63}
# {"ts": "2026-01-22T14:51:25.639Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 4, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 2.89}
# {"ts": "2026-01-22T14:51:25.640Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 5, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 3.37}
# {"ts": "2026-01-22T14:51:25.641Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 6, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 4.26}
# {"ts": "2026-01-22T14:51:25.642Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 7, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 5.46}
# {"ts": "2026-01-22T14:51:25.643Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 8, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 5.96}
# {"ts": "2026-01-22T14:51:25.644Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 9, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 6.64}
# {"ts": "2026-01-22T14:51:25.645Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 10, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 8.46}
# {"ts": "2026-01-22T14:51:25.646Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 11, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 9.0}
# {"ts": "2026-01-22T14:51:25.646Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 12, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 9.41}
# {"ts": "2026-01-22T14:51:25.646Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 13, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 9.92}
# {"ts": "2026-01-22T14:51:25.647Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 14, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 10.43}
# {"ts": "2026-01-22T14:51:25.648Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 15, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 10.96}
# {"ts": "2026-01-22T14:51:25.648Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 16, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 11.7}
# {"ts": "2026-01-22T14:51:25.650Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 17, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 13.46}
# {"ts": "2026-01-22T14:51:25.651Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 18, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 13.99}
# {"ts": "2026-01-22T14:51:25.651Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 19, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 14.51}
# {"ts": "2026-01-22T14:51:25.652Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_dispatch", "task_id": 20, "worker": 0, "method": "eth_blockNumber", "queue_wait_ms": 15.24}
# {"ts": "2026-01-22T14:51:25.652Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 1, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:25.654Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 2, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:25.655Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 3, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:25.657Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 4, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:25.657Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 5, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:26.276Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 6, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:26.484Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 7, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:26.631Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 8, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:26.739Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 9, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:26.947Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 10, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:26.950Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 11, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:27.669Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 12, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:27.679Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 13, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:27.736Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 14, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:27.935Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 15, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:27.937Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 16, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:28.364Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 17, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:28.728Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 18, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:28.771Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 19, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:28.865Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_start", "task_id": 20, "worker": 0, "method": "eth_blockNumber"}
# {"ts": "2026-01-22T14:51:30.245Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 1, "rpc": "nownodes", "key_env": "NOWNODES_KEY_A", "block": 76774744, "latency_ms": 1296.35}
# {"ts": "2026-01-22T14:51:30.246Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 2, "rpc": "moralis", "key_env": "MORALIS_KEY_B", "block": 76774744, "latency_ms": 1083.24}
# {"ts": "2026-01-22T14:51:30.247Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 3, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_A", "block": 76774743, "latency_ms": 827.01}
# {"ts": "2026-01-22T14:51:30.248Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 4, "rpc": "ankr", "key_env": "ANKR_KEY_A", "block": 76774742, "latency_ms": 618.23}
# {"ts": "2026-01-22T14:51:30.248Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 5, "rpc": "infura", "key_env": "INFURA_KEY_A", "block": 76774744, "latency_ms": 1289.11}
# {"ts": "2026-01-22T14:51:30.248Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 6, "rpc": "drpc", "key_env": "DRPC_API_KEY_A", "block": 76774743, "latency_ms": 354.22}
# {"ts": "2026-01-22T14:51:30.249Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 7, "rpc": "infura", "key_env": "INFURA_KEY_B", "block": 76774746, "latency_ms": 1184.32}
# {"ts": "2026-01-22T14:51:30.249Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 8, "rpc": "infura", "key_env": "INFURA_KEY_C", "block": 76774746, "latency_ms": 1304.98}
# {"ts": "2026-01-22T14:51:30.249Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 9, "rpc": "nownodes", "key_env": "NOWNODES_KEY_A", "block": 76774746, "latency_ms": 1194.75}
# {"ts": "2026-01-22T14:51:30.250Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 10, "rpc": "ankr", "key_env": "ANKR_KEY_B", "block": 76774744, "latency_ms": 787.3}
# {"ts": "2026-01-22T14:51:30.250Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 11, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "block": 76774746, "latency_ms": 728.17}
# {"ts": "2026-01-22T14:51:30.251Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 12, "rpc": "infura", "key_env": "INFURA_KEY_A", "block": 76774751, "latency_ms": 2575.75}
# {"ts": "2026-01-22T14:51:30.251Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 13, "rpc": "infura", "key_env": "INFURA_KEY_B", "block": 76774748, "latency_ms": 1184.89}
# {"ts": "2026-01-22T14:51:30.251Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 14, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_B", "block": 76774747, "latency_ms": 627.62}
# {"ts": "2026-01-22T14:51:30.252Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 15, "rpc": "moralis", "key_env": "MORALIS_KEY_B", "block": 76774748, "latency_ms": 835.08}
# {"ts": "2026-01-22T14:51:30.252Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 16, "rpc": "blockpi", "key_env": "BLOCKPI_BSC_KEY_C", "block": 76774748, "latency_ms": 789.87}
# {"ts": "2026-01-22T14:51:30.253Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 17, "rpc": "quiknode", "key_env": "QUIKNODE_KEY", "block": 76774750, "latency_ms": 1184.21}
# {"ts": "2026-01-22T14:51:30.253Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 18, "rpc": "ankr", "key_env": "ANKR_KEY_C", "block": 76774748, "latency_ms": 374.91}
# {"ts": "2026-01-22T14:51:30.253Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 19, "rpc": "nownodes", "key_env": "NOWNODES_KEY_A", "block": 76774750, "latency_ms": 1016.54}
# {"ts": "2026-01-22T14:51:30.254Z", "level": "INFO", "logger": "web3_ingestion", "msg": "rpc_call_done", "task_id": 20, "rpc": "public-thirdweb", "key_env": "public", "block": 76774749, "latency_ms": 411.79}

# %%
# worker as dispatcher - V2
await fetch_and_push()

# %%
async def fetch_and_push():
    client = AsyncRpcClient(timeout=RPC_MAX_TIMEOUT)
    router = Web3AsyncRouter(rpc_pool, client)
    scheduler = AsyncRpcScheduler(
        router,
        max_workers=MAX_WORKERS, # dispatcher 数量
        max_queue=MAX_RPC_REQ,
        max_inflight=5,  #🔥 真正并发 RPC 数 # max_inflight ≈ (provider 数 × key 数) × 0.6
        

    )
    for _ in range(MAX_RPC_REQ):
        result, rpc, key_env, trace, worker_id, meta = await scheduler.submit(
            "eth_blockNumber", []
        )
        block_num = normalize_block(result)
        # log.info(
        #     "rpc_call_done",
        #     extra={
        #         "task_id": meta.task_id,
        #         "worker": worker_id,
        #         "rpc": rpc,
        #         "key_env": key_env,
        #         "block": block_num,
        #         "latency_ms": round(trace.total_ms, 2),
        #         "dns_ms": round(trace.dns_ms, 2),
        #         "tcp_ms": round(trace.tcp_ms, 2),
        #         "http_wait_ms": round(trace.http_wait_ms, 2)
        #     },
        # )

    await scheduler.close()

# %%
# worker as dispatcher  - V1
await fetch_and_push()

# %%
# worker as rpc executor 
# await fetch_and_push()
